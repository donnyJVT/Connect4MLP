# %% [markdown]
# # CSC 671 Deep Learning Final Project - Connect 4 MLP - Fall 2024
# by Donovan Taylor, Joyce Fu, Tyron Cheung, and Randale Reyes (SFSU)

# %% [markdown]
# ## Import our libraries

# %%
# Import necessary libraries
import numpy as np
import random as rand
import ipywidgets as widgets
from IPython.display import display, clear_output
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import torch.nn.functional as F
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ParameterSampler

# %% [markdown]
# # GAME

# %% [markdown]
# ## This is our game logic, this goes at the top and is used by various instances of our game (run first)

# %%
# Function to evaluate the board and get recommended move out of the valid columns
def recommend_valid_move(board, valid_columns):
    # Flatten the board and convert to tensor
    flattened_board = torch.tensor(board.flatten(), dtype=torch.float32)
    # generate our model's output
    output = model(flattened_board)
    new_output = []
    # loop through all 7 possible columns
    for i in range(len(output)):
        # if the current column is a valid column,
        if i in valid_columns:
            # append the current column
            new_output.append(output[i])
        else:
            # else append negative infinity so it's ignored by argmax
            new_output.append(-np.Infinity)
    # generate recommended column from the available columns
    recommended_column = torch.argmax(torch.tensor(new_output)).item()
    return recommended_column

# Function to evaluate the board and get recommended move
def recommend_move(board):
    # Flatten the board and convert to tensor
    flattened_board = torch.tensor(board.flatten(), dtype=torch.float32)
    # generate our model's output
    output = model(flattened_board)
    # generate recommended column
    recommended_column = torch.argmax(output).item()
    return recommended_column

# %%
# Initialize the game board
def initialize_board():
    """Creates an empty 6x7 Connect 4 board."""
    return np.zeros((6, 7))

# Function to check if a location is valid
def is_valid_location(board, col):
    """Checks if a column has space for a new piece."""
    return board[0][col] == 0

# Function to get the next open row in a column
def get_next_open_row(board, col):
    """Finds the next open row in a column for a piece to drop."""
    for r in range(5, -1, -1):
        if board[r][col] == 0:
            return r

# Function to drop a piece into the board
def drop_piece(board, row, col, piece):
    """Drops a piece into the specified row and column."""
    board[row][col] = piece

# Function to check for a winning move and return the winning coordinates
def winning_move(board, piece):
    """Checks if the current move resulted in a win and returns the winning coordinates."""
    # Check horizontal locations for win
    for c in range(4):
        for r in range(5, -1, -1):
            if board[r][c] == piece and board[r][c+1] == piece and board[r][c+2] == piece and board[r][c+3] == piece:
                return True, [(r, c), (r, c+1), (r, c+2), (r, c+3)]

    # Check vertical locations for win
    for c in range(7):
        for r in range(5, 2, -1):
            if board[r][c] == piece and board[r-1][c] == piece and board[r-2][c] == piece and board[r-3][c] == piece:
                return True, [(r, c), (r-1, c), (r-2, c), (r-3, c)]

    # Check positively sloped diagonals
    for c in range(4):
        for r in range(5, 2, -1):
            if board[r][c] == piece and board[r-1][c+1] == piece and board[r-2][c+2] == piece and board[r-3][c+3] == piece:
                return True, [(r, c), (r-1, c+1), (r-2, c+2), (r-3, c+3)]

    # Check negatively sloped diagonals
    for c in range(4):
        for r in range(2, -1, -1):
            if board[r][c] == piece and board[r+1][c+1] == piece and board[r+2][c+2] == piece and board[r+3][c+3] == piece:
                return True, [(r, c), (r+1, c+1), (r+2, c+2), (r+3, c+3)]

    return False, []

# Function to display the board normally
def print_board(board, winning_coords):
    """Prints the board in a readable format."""
    symbol_map = {1: 'x', -1: 'o', 0: '.'}
    for row in range(6):
        for cell in range(7):
          symbol = symbol_map[board[row][cell]]
          if (row, cell) in winning_coords:
            print(f"{symbol.upper()}", end=" ")
          else:
            print(f"{symbol}" , end=" ")
        print()
    print()

# %% [markdown]
# ## (OPTIONAL) Test game loop

# %%
# Main game loop
def game():
    board = initialize_board()
    game_over = False
    player_turn = 1

    # Create interactive buttons
    buttons = []
    for i in range(7):
        button = widgets.Button(description=str(i+1), layout=widgets.Layout(width='30px'))
        button.on_click(lambda b, col=i: drop_piece_and_print(board, col, player_turn))
        buttons.append(button)


    def drop_piece_and_print(board, col, piece):
        nonlocal player_turn, game_over
        if game_over:
            return


        if is_valid_location(board, col):
            clear_output()
            row = get_next_open_row(board, col)
            drop_piece(board, row, col, piece)
            valid_columns = [col for col in range(7) if is_valid_location(board, col)]
            print_board(board, [])
            display(widgets.HBox(buttons))
            print(recommend_move(board) + 1)

            won, winning_coords = winning_move(board, player_turn)
            if won:
                print_board(board, winning_coords)
                winner = "X" if player_turn == 1 else "O"
                print(f"Player {winner} wins!")
                print("Winning coordinates:", winning_coords)
                return player_turn  # Return the winning player


            # Switch players
            player_turn *= -1

    # Display the initial board and buttons
    print_board(board, [])
    display(widgets.HBox(buttons))

# Run the game function to start the game
game()
# Out:
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . x . .
# HBox(children=(Button(description='1', layout=Layout(width='30px'), style=ButtonStyle()), Button(description='…
# 4

# %% [markdown]
# # Generate Dataset

# %% [markdown]
# ## Functions to play simulated games and generate our dataset

# %%
def generate_game_dataset(num_games, output_file="connect4_dataset.csv"):
    """
    Generates a dataset of random games, recording the board state at each move.

    Args:
    - num_games: Number of games to simulate.
    - output_file: File name for the output CSV.

    Output:
    - A CSV file with rows representing games and columns representing moves.
      Each cell contains a flattened 6x7 board state as a list.
    """
    dataset = []

    for game_id in range(num_games):
        board = initialize_board()
        game_states = []  # Stores flattened board states for this game
        game_over = False
        player_turn = rand.choice([-1, 1])  # Random starting player
        moves_played = 0
        max_moves = 42  # Maximum moves for a Connect 4 board

        while moves_played < max_moves and not game_over:
            valid_columns = [col for col in range(7) if is_valid_location(board, col)]
            if not valid_columns:
                break  # No valid moves left

            # Random move
            column = np.random.choice(valid_columns)
            row = get_next_open_row(board, column)
            drop_piece(board, row, column, player_turn)

            dataset.append({
                "Game_ID": game_id,
                "Player": player_turn,
                "Board_State": board.flatten().tolist(),
                "Column_Played": column
            })

            # Check for a win
            won, _ = winning_move(board, player_turn)
            if won: game_over = True

            # Switch player
            player_turn *= -1
            moves_played += 1

    # Convert dataset to a CSV format
    df = pd.DataFrame(dataset)
    df.to_csv(output_file, index=False)
    print(f"Dataset saved to {output_file}")

# %% [markdown]
# ## Actually generate the dataset

# %%
# generate our dataset
generate_game_dataset(1000, "connect4_dataset.csv")
# Out:
# Dataset saved to connect4_dataset.csv

# %% [markdown]
# ## Import our generated dataset and split into train and test data

# %%
import ast

# import our dataset
df = pd.read_csv('connect4_dataset.csv')

# this is where we will store board states of interest, penultimate if X won
# antepenultimate if O wins
penultimate_board_states = []
final_columns_played = []
board_states = []

num_unique_games = df['Game_ID'].nunique()
print(f'{num_unique_games} games loaded.')

for i in range(num_unique_games):
  filtered_df = df[df['Game_ID'] == i]

  winner = filtered_df.iloc[-1]['Player']  # Get outcome for X
  if winner == 1:
    # Penultimate for X win
    board_state = np.array(ast.literal_eval(filtered_df.iloc[-2]['Board_State']))
    penultimate_board_states.append(board_state)
    final_columns_played.append(filtered_df.iloc[-1]['Column_Played'])  # Last move
  elif winner == -1:
    # Antepenultimate for X loss
    board_state = np.array(ast.literal_eval(filtered_df.iloc[-3]['Board_State']))
    penultimate_board_states.append(board_state)
    final_columns_played.append(filtered_df.iloc[-1]['Column_Played'])  # last move

X_train, X_test, y_train, y_test = train_test_split(
    penultimate_board_states, final_columns_played, test_size=0.2, random_state=42)
# Out:
# 1000 games loaded.

# %% [markdown]
# # Dataloader from our above dataset

# %%
print(len(X_train))
# Out:
# 80000

# %%
class Connect4Dataset(Dataset):
  def __init__(self, X, y):
    self.features = torch.tensor(X, dtype=torch.float32)
    self.labels = torch.tensor(y, dtype=torch.float32)

  def __len__(self):
    return len(self.labels)

  def __getitem__(self, idx):
    x = self.features[idx]
    y = self.labels[idx]
    return x, y

train_ds = Connect4Dataset(X_train, y_train)
test_ds = Connect4Dataset(X_test, y_test)


train_loader = DataLoader(train_ds, batch_size=256, shuffle=True)
test_loader = DataLoader(test_ds, batch_size=256, shuffle=True)
# Out:
# <ipython-input-29-ca0fc39c79fd>:3: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   self.features = torch.tensor(X, dtype=torch.float32)

# %%
print(len(train_loader))
# Out:
# 313

# %% [markdown]
# ## Accuracy computation

# %%
def compute_accuracy(model, data_loader):
  """Computes the accuracy of the model using cross-entropy."""
  model.eval()  # Set the model to evaluation mode
  correct_predictions = 0
  total_predictions = 0

  with torch.no_grad():  # Disable gradient calculations for evaluation
    for board_states, target_moves in data_loader:
      # target_moves should be the actual column played
      outputs = model(board_states)  # Get model's predictions

      # Calculate cross-entropy loss
      loss = nn.CrossEntropyLoss()(outputs, target_moves.long())

      # Get predicted moves (argmax of outputs)
      _, predicted_moves = torch.max(outputs, 1)

      # Count correct predictions
      correct_predictions += (predicted_moves == target_moves).sum().item()
      total_predictions += target_moves.size(0)

  accuracy = correct_predictions / total_predictions
  return accuracy

# %% [markdown]
# # MODEL

# %% [markdown]
# ## Implement our model class

# %%
# MLP model for evaluating Connect 4 board
class Connect4MLP(nn.Module):
    def __init__(self, dropout_rate = 0):
        super(Connect4MLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(42, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 7),
        )

    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# # Training Loop

# %% [markdown]
# ## Define our hyperparameter grid to find optimal parmeters

# %%
# this is the parameter grid we intend to search
param_grid = {
    'learning_rate': [0.9, 0.7, 0.5, 0.2],
    'batch_size': [128, 256, 512]
}

# this is the amount of combination we'll try
number_of_iterations = 10

# we randomly select from the above parameter grid
param_list = list(ParameterSampler(param_grid, n_iter=number_of_iterations))

# we keep track of the best accuracy and best hyperparameter combination
best_accuracy = 0
best_params = {}
best_model = None

torch.manual_seed(123)

# we loop through our hyperparameter list
for params in param_list:
  # print the parameters we're working with
  print(params)

  # we initialize our dataloader, varying our batch size
  train_loader = DataLoader(train_ds, batch_size=params['batch_size'], shuffle=True)
  test_loader = DataLoader(test_ds, batch_size=params['batch_size'], shuffle=True)

  # we initialze our model, optimizer, vary our learning rate, and set our number of epochs
  model = Connect4MLP()
  optimizer = torch.optim.SGD(model.parameters(), lr=params['learning_rate'])
  num_epochs = 500

  # variables for early stopping
  best_loss = float('inf')
  patience = 20
  epochs_without_improvement = 0

  # these will be used to make our graphs after each training loop
  loss_by_epoch = []
  train_accuracy_by_epoch = []
  test_accuracy_by_epoch = []

  # begin the training loop with the current hyperparameters
  for epoch in range(num_epochs):
    model = model.train()

    # we keep track of the losses by batch and begin loading our training data
    losses_by_batch = []
    for batch_idx, (boards, moves) in enumerate(train_loader):
      outputs = model(boards)
      loss = F.cross_entropy(outputs, moves.long())

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      losses_by_batch.append(loss.item())

    # we populate the lists that will be used to create our graphs
    loss_by_epoch.append(float(torch.tensor(losses_by_batch).mean()))
    train_accuracy = compute_accuracy(model, train_loader)
    test_accuracy = compute_accuracy(model, test_loader)
    train_accuracy_by_epoch.append(train_accuracy)
    test_accuracy_by_epoch.append(test_accuracy)

    # this is for early stopping
    mean_loss_this_epoch = float(torch.tensor(losses_by_batch).mean())

    # keep track of our best model and whether or not we have exceeded our patience
    if mean_loss_this_epoch < best_loss:
      best_loss = mean_loss_this_epoch
      epochs_without_improvement = 0
      best_model = model.state_dict()
    else:
      epochs_without_improvement += 1
      if epochs_without_improvement >= patience:
        print(f"Early stopping at epoch {epoch + 1}.")
        break

    print(f"Epoch {epoch + 1}, Loss: {mean_loss_this_epoch}, Train Accuracy: {train_accuracy}, Test Accuracy: {test_accuracy}")

  # we plot our loss, train and test accuracy for these hyperparameters
  plt.plot(range(epoch + 1), loss_by_epoch, 'r', label='Loss')
  plt.plot(range(epoch + 1), train_accuracy_by_epoch, 'b', label='Train Accuracy')
  plt.plot(range(epoch + 1), test_accuracy_by_epoch, 'g', label='Test Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Value')
  plt.title(f'parameters {params} train accuracy {train_accuracy} test accuracy {test_accuracy}')
  plt.legend()
  plt.show()

  # keep track of our best accuracy and parameters
  if test_accuracy > best_accuracy:
    best_accuracy = test_accuracy
    best_params = params

  # clear the cache after each training loop for performance.
  torch.cuda.empty_cache()


print(f"Best Accuracy: {best_accuracy}, Best Parameters: {best_params}")
# Out:
# {'learning_rate': 0.2, 'batch_size': 512}
# Epoch 1, Loss: 1.9339094161987305, Train Accuracy: 0.23125, Test Accuracy: 0.19
# Epoch 2, Loss: 1.9210742712020874, Train Accuracy: 0.24625, Test Accuracy: 0.25
# Epoch 3, Loss: 1.9093254804611206, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 4, Loss: 1.9042168855667114, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 5, Loss: 1.8946396112442017, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 6, Loss: 1.8912575244903564, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 7, Loss: 1.884657382965088, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 8, Loss: 1.8788009881973267, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 9, Loss: 1.8742226362228394, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 10, Loss: 1.8721299171447754, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 11, Loss: 1.8616676330566406, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 12, Loss: 1.8712618350982666, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 13, Loss: 1.867546796798706, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 14, Loss: 1.8646372556686401, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 15, Loss: 1.8675432205200195, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 16, Loss: 1.8602099418640137, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 17, Loss: 1.8622300624847412, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 18, Loss: 1.8588002920150757, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 19, Loss: 1.8651169538497925, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 20, Loss: 1.8650968074798584, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 21, Loss: 1.8602919578552246, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 22, Loss: 1.8636267185211182, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 23, Loss: 1.8551604747772217, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 24, Loss: 1.8646655082702637, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 25, Loss: 1.8549506664276123, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 26, Loss: 1.8583221435546875, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 27, Loss: 1.8564702272415161, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 28, Loss: 1.8578627109527588, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 29, Loss: 1.8538459539413452, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 30, Loss: 1.8550124168395996, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 31, Loss: 1.8607993125915527, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 32, Loss: 1.8623454570770264, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 33, Loss: 1.8547801971435547, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 34, Loss: 1.8540384769439697, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 35, Loss: 1.8571314811706543, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 36, Loss: 1.8492623567581177, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 37, Loss: 1.8525481224060059, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 38, Loss: 1.855031967163086, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 39, Loss: 1.8549001216888428, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 40, Loss: 1.847874402999878, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 41, Loss: 1.8461430072784424, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 42, Loss: 1.8493095636367798, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 43, Loss: 1.8453353643417358, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 44, Loss: 1.8527461290359497, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 45, Loss: 1.8447558879852295, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 46, Loss: 1.854650616645813, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 47, Loss: 1.8507938385009766, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 48, Loss: 1.8455123901367188, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 49, Loss: 1.851772427558899, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 50, Loss: 1.8476241827011108, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 51, Loss: 1.8457934856414795, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 52, Loss: 1.8470613956451416, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 53, Loss: 1.8424615859985352, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 54, Loss: 1.8424532413482666, Train Accuracy: 0.25125, Test Accuracy: 0.265
# Epoch 55, Loss: 1.8436460494995117, Train Accuracy: 0.25375, Test Accuracy: 0.27
# Epoch 56, Loss: 1.8403160572052002, Train Accuracy: 0.2525, Test Accuracy: 0.265
# Epoch 57, Loss: 1.8370957374572754, Train Accuracy: 0.2575, Test Accuracy: 0.27
# Epoch 58, Loss: 1.842031478881836, Train Accuracy: 0.25875, Test Accuracy: 0.27
# Epoch 59, Loss: 1.8384931087493896, Train Accuracy: 0.25875, Test Accuracy: 0.27
# Epoch 60, Loss: 1.8373421430587769, Train Accuracy: 0.25875, Test Accuracy: 0.27
# Epoch 61, Loss: 1.840374231338501, Train Accuracy: 0.26375, Test Accuracy: 0.27
# Epoch 62, Loss: 1.8371121883392334, Train Accuracy: 0.26375, Test Accuracy: 0.27
# Epoch 63, Loss: 1.8367431163787842, Train Accuracy: 0.26375, Test Accuracy: 0.27
# Epoch 64, Loss: 1.832617163658142, Train Accuracy: 0.26375, Test Accuracy: 0.265
# Epoch 65, Loss: 1.8361828327178955, Train Accuracy: 0.265, Test Accuracy: 0.265
# Epoch 66, Loss: 1.830196738243103, Train Accuracy: 0.265, Test Accuracy: 0.265
# Epoch 67, Loss: 1.8291033506393433, Train Accuracy: 0.265, Test Accuracy: 0.265
# Epoch 68, Loss: 1.8340389728546143, Train Accuracy: 0.265, Test Accuracy: 0.265
# Epoch 69, Loss: 1.8275561332702637, Train Accuracy: 0.26625, Test Accuracy: 0.265
# Epoch 70, Loss: 1.8283852338790894, Train Accuracy: 0.26625, Test Accuracy: 0.265
# Epoch 71, Loss: 1.826748251914978, Train Accuracy: 0.2675, Test Accuracy: 0.26
# Epoch 72, Loss: 1.8322068452835083, Train Accuracy: 0.2675, Test Accuracy: 0.26
# Epoch 73, Loss: 1.8258347511291504, Train Accuracy: 0.26625, Test Accuracy: 0.26
# Epoch 74, Loss: 1.8268842697143555, Train Accuracy: 0.26875, Test Accuracy: 0.265
# Epoch 75, Loss: 1.8260746002197266, Train Accuracy: 0.27125, Test Accuracy: 0.265
# Epoch 76, Loss: 1.8218467235565186, Train Accuracy: 0.26875, Test Accuracy: 0.26
# Epoch 77, Loss: 1.815889835357666, Train Accuracy: 0.27125, Test Accuracy: 0.265
# Epoch 78, Loss: 1.8173954486846924, Train Accuracy: 0.27625, Test Accuracy: 0.265
# Epoch 79, Loss: 1.818019151687622, Train Accuracy: 0.28, Test Accuracy: 0.265
# Epoch 80, Loss: 1.8128247261047363, Train Accuracy: 0.28875, Test Accuracy: 0.27
# Epoch 81, Loss: 1.8160004615783691, Train Accuracy: 0.29625, Test Accuracy: 0.265
# Epoch 82, Loss: 1.8115962743759155, Train Accuracy: 0.29375, Test Accuracy: 0.265
# Epoch 83, Loss: 1.8076255321502686, Train Accuracy: 0.29625, Test Accuracy: 0.265
# Epoch 84, Loss: 1.8031368255615234, Train Accuracy: 0.2975, Test Accuracy: 0.26
# Epoch 85, Loss: 1.8068263530731201, Train Accuracy: 0.3025, Test Accuracy: 0.26
# Epoch 86, Loss: 1.8046691417694092, Train Accuracy: 0.29375, Test Accuracy: 0.265
# Epoch 87, Loss: 1.8005385398864746, Train Accuracy: 0.29875, Test Accuracy: 0.26
# Epoch 88, Loss: 1.7935278415679932, Train Accuracy: 0.3025, Test Accuracy: 0.26
# Epoch 89, Loss: 1.7991751432418823, Train Accuracy: 0.3075, Test Accuracy: 0.25
# Epoch 90, Loss: 1.7867647409439087, Train Accuracy: 0.30875, Test Accuracy: 0.255
# Epoch 91, Loss: 1.7903733253479004, Train Accuracy: 0.3075, Test Accuracy: 0.26
# Epoch 92, Loss: 1.7842669486999512, Train Accuracy: 0.31, Test Accuracy: 0.255
# Epoch 93, Loss: 1.78135085105896, Train Accuracy: 0.3075, Test Accuracy: 0.26
# Epoch 94, Loss: 1.7777459621429443, Train Accuracy: 0.30875, Test Accuracy: 0.26
# Epoch 95, Loss: 1.787003755569458, Train Accuracy: 0.31, Test Accuracy: 0.255
# Epoch 96, Loss: 1.7720589637756348, Train Accuracy: 0.31, Test Accuracy: 0.26
# Epoch 97, Loss: 1.7767937183380127, Train Accuracy: 0.30875, Test Accuracy: 0.275
# Epoch 98, Loss: 1.7648301124572754, Train Accuracy: 0.31, Test Accuracy: 0.27
# Epoch 99, Loss: 1.7594990730285645, Train Accuracy: 0.3125, Test Accuracy: 0.26
# Epoch 100, Loss: 1.7549455165863037, Train Accuracy: 0.3125, Test Accuracy: 0.26
# Epoch 101, Loss: 1.768627643585205, Train Accuracy: 0.315, Test Accuracy: 0.27
# Epoch 102, Loss: 1.7609148025512695, Train Accuracy: 0.31625, Test Accuracy: 0.265
# Epoch 103, Loss: 1.7501925230026245, Train Accuracy: 0.325, Test Accuracy: 0.275
# Epoch 104, Loss: 1.7478305101394653, Train Accuracy: 0.325, Test Accuracy: 0.275
# Epoch 105, Loss: 1.7410653829574585, Train Accuracy: 0.3225, Test Accuracy: 0.265
# Epoch 106, Loss: 1.7343809604644775, Train Accuracy: 0.32375, Test Accuracy: 0.265
# Epoch 107, Loss: 1.7377300262451172, Train Accuracy: 0.33, Test Accuracy: 0.265
# Epoch 108, Loss: 1.7458429336547852, Train Accuracy: 0.3375, Test Accuracy: 0.26
# Epoch 109, Loss: 1.725066900253296, Train Accuracy: 0.33875, Test Accuracy: 0.265
# Epoch 110, Loss: 1.728896141052246, Train Accuracy: 0.34, Test Accuracy: 0.265
# Epoch 111, Loss: 1.7258892059326172, Train Accuracy: 0.33625, Test Accuracy: 0.27
# Epoch 112, Loss: 1.7125349044799805, Train Accuracy: 0.35375, Test Accuracy: 0.26
# Epoch 113, Loss: 1.7165340185165405, Train Accuracy: 0.3475, Test Accuracy: 0.24
# Epoch 114, Loss: 1.7084369659423828, Train Accuracy: 0.3475, Test Accuracy: 0.27
# Epoch 115, Loss: 1.7017204761505127, Train Accuracy: 0.34875, Test Accuracy: 0.275
# Epoch 116, Loss: 1.695556879043579, Train Accuracy: 0.35125, Test Accuracy: 0.275
# Epoch 117, Loss: 1.6864252090454102, Train Accuracy: 0.36125, Test Accuracy: 0.275
# Epoch 118, Loss: 1.6873875856399536, Train Accuracy: 0.36, Test Accuracy: 0.23
# Epoch 119, Loss: 1.6694505214691162, Train Accuracy: 0.36875, Test Accuracy: 0.275
# Epoch 120, Loss: 1.675109624862671, Train Accuracy: 0.37125, Test Accuracy: 0.275
# Epoch 121, Loss: 1.660345435142517, Train Accuracy: 0.36875, Test Accuracy: 0.25
# Epoch 122, Loss: 1.6492716073989868, Train Accuracy: 0.375, Test Accuracy: 0.275
# Epoch 123, Loss: 1.6468839645385742, Train Accuracy: 0.3725, Test Accuracy: 0.21
# Epoch 124, Loss: 1.6420797109603882, Train Accuracy: 0.3825, Test Accuracy: 0.275
# Epoch 125, Loss: 1.6463786363601685, Train Accuracy: 0.3725, Test Accuracy: 0.205
# Epoch 126, Loss: 1.6369706392288208, Train Accuracy: 0.3825, Test Accuracy: 0.26
# Epoch 127, Loss: 1.6223820447921753, Train Accuracy: 0.3875, Test Accuracy: 0.255
# Epoch 128, Loss: 1.6054062843322754, Train Accuracy: 0.39375, Test Accuracy: 0.265
# Epoch 129, Loss: 1.5974748134613037, Train Accuracy: 0.385, Test Accuracy: 0.22
# Epoch 130, Loss: 1.6080076694488525, Train Accuracy: 0.3875, Test Accuracy: 0.21
# Epoch 131, Loss: 1.6131819486618042, Train Accuracy: 0.39875, Test Accuracy: 0.215
# Epoch 132, Loss: 1.5832899808883667, Train Accuracy: 0.40625, Test Accuracy: 0.26
# Epoch 133, Loss: 1.5736017227172852, Train Accuracy: 0.3975, Test Accuracy: 0.215
# Epoch 134, Loss: 1.5621367692947388, Train Accuracy: 0.41, Test Accuracy: 0.23
# Epoch 135, Loss: 1.5709242820739746, Train Accuracy: 0.4175, Test Accuracy: 0.215
# Epoch 136, Loss: 1.5448033809661865, Train Accuracy: 0.43375, Test Accuracy: 0.24
# Epoch 137, Loss: 1.5193512439727783, Train Accuracy: 0.425, Test Accuracy: 0.275
# Epoch 138, Loss: 1.5103137493133545, Train Accuracy: 0.44375, Test Accuracy: 0.29
# Epoch 139, Loss: 1.507214903831482, Train Accuracy: 0.4075, Test Accuracy: 0.3
# Epoch 140, Loss: 1.507873296737671, Train Accuracy: 0.435, Test Accuracy: 0.305
# Epoch 141, Loss: 1.4910194873809814, Train Accuracy: 0.4625, Test Accuracy: 0.3
# Epoch 142, Loss: 1.4686174392700195, Train Accuracy: 0.415, Test Accuracy: 0.305
# Epoch 143, Loss: 1.498749017715454, Train Accuracy: 0.38875, Test Accuracy: 0.29
# Epoch 144, Loss: 1.4946401119232178, Train Accuracy: 0.465, Test Accuracy: 0.34
# Epoch 145, Loss: 1.4512228965759277, Train Accuracy: 0.45, Test Accuracy: 0.31
# Epoch 146, Loss: 1.4500713348388672, Train Accuracy: 0.41, Test Accuracy: 0.3
# Epoch 147, Loss: 1.5094177722930908, Train Accuracy: 0.36875, Test Accuracy: 0.295
# Epoch 148, Loss: 1.568150281906128, Train Accuracy: 0.40375, Test Accuracy: 0.295
# Epoch 149, Loss: 1.4722081422805786, Train Accuracy: 0.45125, Test Accuracy: 0.315
# Epoch 150, Loss: 1.4026439189910889, Train Accuracy: 0.46125, Test Accuracy: 0.32
# Epoch 151, Loss: 1.3971683979034424, Train Accuracy: 0.495, Test Accuracy: 0.31
# Epoch 152, Loss: 1.3784347772598267, Train Accuracy: 0.485, Test Accuracy: 0.3
# Epoch 153, Loss: 1.4297553300857544, Train Accuracy: 0.36125, Test Accuracy: 0.295
# Epoch 154, Loss: 1.5602028369903564, Train Accuracy: 0.4525, Test Accuracy: 0.295
# Epoch 155, Loss: 1.4185433387756348, Train Accuracy: 0.4475, Test Accuracy: 0.305
# Epoch 156, Loss: 1.4329371452331543, Train Accuracy: 0.43125, Test Accuracy: 0.3
# Epoch 157, Loss: 1.4409644603729248, Train Accuracy: 0.4, Test Accuracy: 0.295
# Epoch 158, Loss: 1.4862463474273682, Train Accuracy: 0.48625, Test Accuracy: 0.275
# Epoch 159, Loss: 1.3500643968582153, Train Accuracy: 0.515, Test Accuracy: 0.335
# Epoch 160, Loss: 1.3065826892852783, Train Accuracy: 0.51125, Test Accuracy: 0.31
# Epoch 161, Loss: 1.3242950439453125, Train Accuracy: 0.5125, Test Accuracy: 0.315
# Epoch 162, Loss: 1.3286446332931519, Train Accuracy: 0.4475, Test Accuracy: 0.295
# Epoch 163, Loss: 1.3903942108154297, Train Accuracy: 0.445, Test Accuracy: 0.315
# Epoch 164, Loss: 1.4027073383331299, Train Accuracy: 0.4725, Test Accuracy: 0.32
# Epoch 165, Loss: 1.36593759059906, Train Accuracy: 0.47375, Test Accuracy: 0.3
# Epoch 166, Loss: 1.3062143325805664, Train Accuracy: 0.56875, Test Accuracy: 0.32
# Epoch 167, Loss: 1.220646619796753, Train Accuracy: 0.585, Test Accuracy: 0.295
# Epoch 168, Loss: 1.1786353588104248, Train Accuracy: 0.59125, Test Accuracy: 0.305
# Epoch 169, Loss: 1.1651372909545898, Train Accuracy: 0.52625, Test Accuracy: 0.32
# Epoch 170, Loss: 1.199706792831421, Train Accuracy: 0.53375, Test Accuracy: 0.29
# Epoch 171, Loss: 1.175161361694336, Train Accuracy: 0.56375, Test Accuracy: 0.3
# Epoch 172, Loss: 1.1374319791793823, Train Accuracy: 0.58125, Test Accuracy: 0.315
# Epoch 173, Loss: 1.156914472579956, Train Accuracy: 0.4725, Test Accuracy: 0.3
# Epoch 174, Loss: 1.5035605430603027, Train Accuracy: 0.375, Test Accuracy: 0.275
# Epoch 175, Loss: 1.4252969026565552, Train Accuracy: 0.59, Test Accuracy: 0.33
# Epoch 176, Loss: 1.1410653591156006, Train Accuracy: 0.62625, Test Accuracy: 0.315
# Epoch 177, Loss: 1.0888326168060303, Train Accuracy: 0.61375, Test Accuracy: 0.305
# Epoch 178, Loss: 1.101621389389038, Train Accuracy: 0.59625, Test Accuracy: 0.295
# Epoch 179, Loss: 1.1022400856018066, Train Accuracy: 0.585, Test Accuracy: 0.31
# Epoch 180, Loss: 1.1289279460906982, Train Accuracy: 0.53125, Test Accuracy: 0.33
# Epoch 181, Loss: 1.2114337682724, Train Accuracy: 0.57, Test Accuracy: 0.34
# Epoch 182, Loss: 1.2031211853027344, Train Accuracy: 0.4975, Test Accuracy: 0.31
# Epoch 183, Loss: 1.3232872486114502, Train Accuracy: 0.51875, Test Accuracy: 0.3
# Epoch 184, Loss: 1.201096773147583, Train Accuracy: 0.625, Test Accuracy: 0.33
# Epoch 185, Loss: 1.0530463457107544, Train Accuracy: 0.66875, Test Accuracy: 0.325
# Epoch 186, Loss: 0.9805933237075806, Train Accuracy: 0.68625, Test Accuracy: 0.32
# Epoch 187, Loss: 0.9422388672828674, Train Accuracy: 0.5925, Test Accuracy: 0.33
# Epoch 188, Loss: 1.1368772983551025, Train Accuracy: 0.465, Test Accuracy: 0.275
# Epoch 189, Loss: 1.5596730709075928, Train Accuracy: 0.62875, Test Accuracy: 0.265
# Epoch 190, Loss: 0.9993739724159241, Train Accuracy: 0.63625, Test Accuracy: 0.285
# Epoch 191, Loss: 0.9474843740463257, Train Accuracy: 0.66125, Test Accuracy: 0.315
# Epoch 192, Loss: 0.9299455881118774, Train Accuracy: 0.63625, Test Accuracy: 0.29
# Epoch 193, Loss: 0.9390209317207336, Train Accuracy: 0.655, Test Accuracy: 0.3
# Epoch 194, Loss: 0.9104436635971069, Train Accuracy: 0.66, Test Accuracy: 0.31
# Epoch 195, Loss: 0.932253360748291, Train Accuracy: 0.57125, Test Accuracy: 0.315
# Epoch 196, Loss: 1.0331494808197021, Train Accuracy: 0.62375, Test Accuracy: 0.3
# Epoch 197, Loss: 0.950040340423584, Train Accuracy: 0.6075, Test Accuracy: 0.27
# Epoch 198, Loss: 1.1458244323730469, Train Accuracy: 0.495, Test Accuracy: 0.24
# Epoch 199, Loss: 1.4051570892333984, Train Accuracy: 0.665, Test Accuracy: 0.24
# Epoch 200, Loss: 1.0637907981872559, Train Accuracy: 0.64, Test Accuracy: 0.215
# Epoch 201, Loss: 1.053359031677246, Train Accuracy: 0.75125, Test Accuracy: 0.26
# Epoch 202, Loss: 0.87020343542099, Train Accuracy: 0.78875, Test Accuracy: 0.26
# Epoch 203, Loss: 0.7959477305412292, Train Accuracy: 0.795, Test Accuracy: 0.26
# Epoch 204, Loss: 0.762344241142273, Train Accuracy: 0.79875, Test Accuracy: 0.275
# Epoch 205, Loss: 0.7528718709945679, Train Accuracy: 0.8025, Test Accuracy: 0.27
# Epoch 206, Loss: 0.7722602486610413, Train Accuracy: 0.77, Test Accuracy: 0.27
# Epoch 207, Loss: 0.9192914962768555, Train Accuracy: 0.49, Test Accuracy: 0.195
# Epoch 208, Loss: 1.1439716815948486, Train Accuracy: 0.71125, Test Accuracy: 0.26
# Epoch 209, Loss: 0.8277589082717896, Train Accuracy: 0.83, Test Accuracy: 0.28
# Epoch 210, Loss: 0.677930474281311, Train Accuracy: 0.82875, Test Accuracy: 0.295
# Epoch 211, Loss: 0.637808084487915, Train Accuracy: 0.81, Test Accuracy: 0.3
# Epoch 212, Loss: 0.6319571733474731, Train Accuracy: 0.8325, Test Accuracy: 0.26
# Epoch 213, Loss: 0.6216791868209839, Train Accuracy: 0.83625, Test Accuracy: 0.28
# Epoch 214, Loss: 0.6208033561706543, Train Accuracy: 0.8175, Test Accuracy: 0.28
# Epoch 215, Loss: 0.8508703708648682, Train Accuracy: 0.39375, Test Accuracy: 0.21
# Epoch 216, Loss: 1.897374153137207, Train Accuracy: 0.7, Test Accuracy: 0.265
# Epoch 217, Loss: 0.8274365663528442, Train Accuracy: 0.8275, Test Accuracy: 0.25
# Epoch 218, Loss: 0.6873139142990112, Train Accuracy: 0.865, Test Accuracy: 0.265
# Epoch 219, Loss: 0.6116565465927124, Train Accuracy: 0.86375, Test Accuracy: 0.255
# Epoch 220, Loss: 0.584347128868103, Train Accuracy: 0.8775, Test Accuracy: 0.26
# Epoch 221, Loss: 0.5879114866256714, Train Accuracy: 0.8675, Test Accuracy: 0.275
# Epoch 222, Loss: 0.5687838196754456, Train Accuracy: 0.86375, Test Accuracy: 0.245
# Epoch 223, Loss: 0.6036189198493958, Train Accuracy: 0.7925, Test Accuracy: 0.25
# Epoch 224, Loss: 0.7765695452690125, Train Accuracy: 0.54625, Test Accuracy: 0.17
# Epoch 225, Loss: 1.180485486984253, Train Accuracy: 0.5525, Test Accuracy: 0.18
# Epoch 226, Loss: 1.0210413932800293, Train Accuracy: 0.715, Test Accuracy: 0.3
# Epoch 227, Loss: 0.738213300704956, Train Accuracy: 0.82, Test Accuracy: 0.32
# Epoch 228, Loss: 0.5914254188537598, Train Accuracy: 0.855, Test Accuracy: 0.315
# Epoch 229, Loss: 0.5227755904197693, Train Accuracy: 0.88625, Test Accuracy: 0.335
# Epoch 230, Loss: 0.46010181307792664, Train Accuracy: 0.89, Test Accuracy: 0.31
# Epoch 231, Loss: 0.44702091813087463, Train Accuracy: 0.90625, Test Accuracy: 0.29
# Epoch 232, Loss: 0.4273054897785187, Train Accuracy: 0.9075, Test Accuracy: 0.3
# Epoch 233, Loss: 0.41009950637817383, Train Accuracy: 0.9175, Test Accuracy: 0.285
# Epoch 234, Loss: 0.3913954198360443, Train Accuracy: 0.92, Test Accuracy: 0.305
# Epoch 235, Loss: 0.38634371757507324, Train Accuracy: 0.9175, Test Accuracy: 0.3
# Epoch 236, Loss: 0.3823543190956116, Train Accuracy: 0.92375, Test Accuracy: 0.305
# Epoch 237, Loss: 0.36477920413017273, Train Accuracy: 0.935, Test Accuracy: 0.3
# Epoch 238, Loss: 0.36022162437438965, Train Accuracy: 0.94, Test Accuracy: 0.265
# Epoch 239, Loss: 0.34987667202949524, Train Accuracy: 0.93625, Test Accuracy: 0.295
# Epoch 240, Loss: 0.34005844593048096, Train Accuracy: 0.9475, Test Accuracy: 0.3
# Epoch 241, Loss: 0.32304972410202026, Train Accuracy: 0.94625, Test Accuracy: 0.27
# Epoch 242, Loss: 0.31424254179000854, Train Accuracy: 0.95625, Test Accuracy: 0.27
# Epoch 243, Loss: 0.2999008297920227, Train Accuracy: 0.95375, Test Accuracy: 0.29
# Epoch 244, Loss: 0.30267736315727234, Train Accuracy: 0.95625, Test Accuracy: 0.3
# Epoch 245, Loss: 0.2956414818763733, Train Accuracy: 0.95875, Test Accuracy: 0.305
# Epoch 246, Loss: 0.2882131338119507, Train Accuracy: 0.9575, Test Accuracy: 0.315
# Epoch 247, Loss: 0.2713055908679962, Train Accuracy: 0.9575, Test Accuracy: 0.315
# Epoch 248, Loss: 0.26828068494796753, Train Accuracy: 0.9625, Test Accuracy: 0.295
# Epoch 249, Loss: 0.2654734253883362, Train Accuracy: 0.96, Test Accuracy: 0.285
# Epoch 250, Loss: 0.2573860287666321, Train Accuracy: 0.96625, Test Accuracy: 0.285
# Epoch 251, Loss: 0.24755613505840302, Train Accuracy: 0.9725, Test Accuracy: 0.3
# Epoch 252, Loss: 0.2325718104839325, Train Accuracy: 0.975, Test Accuracy: 0.305
# Epoch 253, Loss: 0.22587233781814575, Train Accuracy: 0.97375, Test Accuracy: 0.305
# Epoch 254, Loss: 0.22913005948066711, Train Accuracy: 0.97375, Test Accuracy: 0.295
# Epoch 255, Loss: 0.22667720913887024, Train Accuracy: 0.9725, Test Accuracy: 0.285
# Epoch 256, Loss: 0.21663889288902283, Train Accuracy: 0.97875, Test Accuracy: 0.295
# Epoch 257, Loss: 0.20910635590553284, Train Accuracy: 0.97875, Test Accuracy: 0.3
# Epoch 258, Loss: 0.20623956620693207, Train Accuracy: 0.98125, Test Accuracy: 0.3
# Epoch 259, Loss: 0.19559724628925323, Train Accuracy: 0.98, Test Accuracy: 0.3
# Epoch 260, Loss: 0.1894105225801468, Train Accuracy: 0.9825, Test Accuracy: 0.31
# Epoch 261, Loss: 0.19107726216316223, Train Accuracy: 0.98375, Test Accuracy: 0.3
# Epoch 262, Loss: 0.17754235863685608, Train Accuracy: 0.98375, Test Accuracy: 0.305
# Epoch 263, Loss: 0.17406120896339417, Train Accuracy: 0.98, Test Accuracy: 0.305
# Epoch 264, Loss: 0.17260980606079102, Train Accuracy: 0.98375, Test Accuracy: 0.3
# Epoch 265, Loss: 0.16362881660461426, Train Accuracy: 0.98625, Test Accuracy: 0.295
# Epoch 266, Loss: 0.163920596241951, Train Accuracy: 0.985, Test Accuracy: 0.31
# Epoch 267, Loss: 0.15588155388832092, Train Accuracy: 0.985, Test Accuracy: 0.29
# Epoch 268, Loss: 0.14899778366088867, Train Accuracy: 0.98625, Test Accuracy: 0.3
# Epoch 269, Loss: 0.1548376828432083, Train Accuracy: 0.98875, Test Accuracy: 0.285
# Epoch 270, Loss: 0.1512959897518158, Train Accuracy: 0.98625, Test Accuracy: 0.315
# Epoch 271, Loss: 0.14271947741508484, Train Accuracy: 0.98625, Test Accuracy: 0.32
# Epoch 272, Loss: 0.14063435792922974, Train Accuracy: 0.985, Test Accuracy: 0.32
# Epoch 273, Loss: 0.13390284776687622, Train Accuracy: 0.9875, Test Accuracy: 0.325
# Epoch 274, Loss: 0.1306542456150055, Train Accuracy: 0.99125, Test Accuracy: 0.3
# Epoch 275, Loss: 0.12683510780334473, Train Accuracy: 0.99125, Test Accuracy: 0.305
# Epoch 276, Loss: 0.12144786864519119, Train Accuracy: 0.99375, Test Accuracy: 0.315
# Epoch 277, Loss: 0.11743761599063873, Train Accuracy: 0.995, Test Accuracy: 0.305
# Epoch 278, Loss: 0.11636011302471161, Train Accuracy: 0.995, Test Accuracy: 0.305
# Epoch 279, Loss: 0.11001557111740112, Train Accuracy: 0.995, Test Accuracy: 0.32
# Epoch 280, Loss: 0.10809409618377686, Train Accuracy: 0.995, Test Accuracy: 0.335
# Epoch 281, Loss: 0.10724422335624695, Train Accuracy: 0.99375, Test Accuracy: 0.325
# Epoch 282, Loss: 0.1040203720331192, Train Accuracy: 0.99625, Test Accuracy: 0.33
# Epoch 283, Loss: 0.09821062535047531, Train Accuracy: 0.99625, Test Accuracy: 0.34
# Epoch 284, Loss: 0.0942225307226181, Train Accuracy: 0.99625, Test Accuracy: 0.32
# Epoch 285, Loss: 0.09481646120548248, Train Accuracy: 0.9975, Test Accuracy: 0.335
# Epoch 286, Loss: 0.09317709505558014, Train Accuracy: 0.995, Test Accuracy: 0.32
# Epoch 287, Loss: 0.08826851844787598, Train Accuracy: 0.9975, Test Accuracy: 0.32
# Epoch 288, Loss: 0.08733892440795898, Train Accuracy: 0.99625, Test Accuracy: 0.3
# Epoch 289, Loss: 0.08561795949935913, Train Accuracy: 0.9975, Test Accuracy: 0.33
# Epoch 290, Loss: 0.07964223623275757, Train Accuracy: 0.9975, Test Accuracy: 0.32
# Epoch 291, Loss: 0.08175692707300186, Train Accuracy: 0.9975, Test Accuracy: 0.32
# Epoch 292, Loss: 0.0784660205245018, Train Accuracy: 0.9975, Test Accuracy: 0.32
# Epoch 293, Loss: 0.07203055918216705, Train Accuracy: 0.9975, Test Accuracy: 0.32
# Epoch 294, Loss: 0.07157354056835175, Train Accuracy: 0.9975, Test Accuracy: 0.325
# Epoch 295, Loss: 0.07092160731554031, Train Accuracy: 0.9975, Test Accuracy: 0.32
# Epoch 296, Loss: 0.0682516098022461, Train Accuracy: 0.99875, Test Accuracy: 0.315
# Epoch 297, Loss: 0.06607134640216827, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 298, Loss: 0.0670953020453453, Train Accuracy: 0.99875, Test Accuracy: 0.325
# Epoch 299, Loss: 0.06501652300357819, Train Accuracy: 0.9975, Test Accuracy: 0.325
# Epoch 300, Loss: 0.06394961476325989, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 301, Loss: 0.06154344230890274, Train Accuracy: 0.99875, Test Accuracy: 0.32
# Epoch 302, Loss: 0.059128329157829285, Train Accuracy: 0.99875, Test Accuracy: 0.32
# Epoch 303, Loss: 0.0564114972949028, Train Accuracy: 0.99875, Test Accuracy: 0.33
# Epoch 304, Loss: 0.05677026882767677, Train Accuracy: 1.0, Test Accuracy: 0.31
# Epoch 305, Loss: 0.057374611496925354, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 306, Loss: 0.05294991284608841, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 307, Loss: 0.053176283836364746, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 308, Loss: 0.05063467472791672, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 309, Loss: 0.04978243261575699, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 310, Loss: 0.04979953169822693, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 311, Loss: 0.04670187830924988, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 312, Loss: 0.04777359962463379, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 313, Loss: 0.0453893207013607, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 314, Loss: 0.047137536108493805, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 315, Loss: 0.0435909777879715, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 316, Loss: 0.042419545352458954, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 317, Loss: 0.04135223478078842, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 318, Loss: 0.04094751924276352, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 319, Loss: 0.039991214871406555, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 320, Loss: 0.03947541117668152, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 321, Loss: 0.038569629192352295, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 322, Loss: 0.03791828453540802, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 323, Loss: 0.03727218881249428, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 324, Loss: 0.036754362285137177, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 325, Loss: 0.03554936498403549, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 326, Loss: 0.034561388194561005, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 327, Loss: 0.033931657671928406, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 328, Loss: 0.03421277552843094, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 329, Loss: 0.03310604393482208, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 330, Loss: 0.031634826213121414, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 331, Loss: 0.03140910714864731, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 332, Loss: 0.03121974691748619, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 333, Loss: 0.030398305505514145, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 334, Loss: 0.030579164624214172, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 335, Loss: 0.030401507392525673, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 336, Loss: 0.02979801595211029, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 337, Loss: 0.028320977464318275, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 338, Loss: 0.02785019762814045, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 339, Loss: 0.0280305128544569, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 340, Loss: 0.028068531304597855, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 341, Loss: 0.026551038026809692, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 342, Loss: 0.026467058807611465, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 343, Loss: 0.025474676862359047, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 344, Loss: 0.02644392102956772, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 345, Loss: 0.025058772414922714, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 346, Loss: 0.025332901626825333, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 347, Loss: 0.02431918866932392, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 348, Loss: 0.024058379232883453, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 349, Loss: 0.024369101971387863, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 350, Loss: 0.02342103235423565, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 351, Loss: 0.023656059056520462, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 352, Loss: 0.02276574820280075, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 353, Loss: 0.022166553884744644, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 354, Loss: 0.02128298580646515, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 355, Loss: 0.02172667905688286, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 356, Loss: 0.021102862432599068, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 357, Loss: 0.020683929324150085, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 358, Loss: 0.020353427156805992, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 359, Loss: 0.02056650072336197, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 360, Loss: 0.020538445562124252, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 361, Loss: 0.019721826538443565, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 362, Loss: 0.019601453095674515, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 363, Loss: 0.01912838965654373, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 364, Loss: 0.020043592900037766, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 365, Loss: 0.018488232046365738, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 366, Loss: 0.018865033984184265, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 367, Loss: 0.018479254096746445, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 368, Loss: 0.018238648772239685, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 369, Loss: 0.017948169261217117, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 370, Loss: 0.01818550005555153, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 371, Loss: 0.01677526906132698, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 372, Loss: 0.017394989728927612, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 373, Loss: 0.017190590500831604, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 374, Loss: 0.01658083312213421, Train Accuracy: 1.0, Test Accuracy: 0.33
# Epoch 375, Loss: 0.016408683732151985, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 376, Loss: 0.016407832503318787, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 377, Loss: 0.016252875328063965, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 378, Loss: 0.015771908685564995, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 379, Loss: 0.015450818464159966, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 380, Loss: 0.01571548730134964, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 381, Loss: 0.015130339190363884, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 382, Loss: 0.015049416571855545, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 383, Loss: 0.014759658835828304, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 384, Loss: 0.01512577012181282, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 385, Loss: 0.014545765705406666, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 386, Loss: 0.014190344139933586, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 387, Loss: 0.014510951936244965, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 388, Loss: 0.01375613734126091, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 389, Loss: 0.014025337994098663, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 390, Loss: 0.014212401583790779, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 391, Loss: 0.013725513592362404, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 392, Loss: 0.013479232788085938, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 393, Loss: 0.013495254330337048, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 394, Loss: 0.013114135712385178, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 395, Loss: 0.013034570962190628, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 396, Loss: 0.01317332498729229, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 397, Loss: 0.012719915248453617, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 398, Loss: 0.013080389238893986, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 399, Loss: 0.012482274323701859, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 400, Loss: 0.012373752892017365, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 401, Loss: 0.01274790521711111, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 402, Loss: 0.012006115168333054, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 403, Loss: 0.011948229745030403, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 404, Loss: 0.011778164654970169, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 405, Loss: 0.011979863047599792, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 406, Loss: 0.01175419706851244, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 407, Loss: 0.011465759947896004, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 408, Loss: 0.011180410161614418, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 409, Loss: 0.010930830612778664, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 410, Loss: 0.011352322064340115, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 411, Loss: 0.01134435459971428, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 412, Loss: 0.011048834770917892, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 413, Loss: 0.010939527302980423, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 414, Loss: 0.010585421696305275, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 415, Loss: 0.010911233723163605, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 416, Loss: 0.010746365413069725, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 417, Loss: 0.01061214692890644, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 418, Loss: 0.010203111916780472, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 419, Loss: 0.01031829696148634, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 420, Loss: 0.010106153786182404, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 421, Loss: 0.01030188798904419, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 422, Loss: 0.009939685463905334, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 423, Loss: 0.009929093532264233, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 424, Loss: 0.009691188111901283, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 425, Loss: 0.009884613566100597, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 426, Loss: 0.009604495018720627, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 427, Loss: 0.00952964834868908, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 428, Loss: 0.009433052502572536, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 429, Loss: 0.00954187847673893, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 430, Loss: 0.009325187653303146, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 431, Loss: 0.009577534161508083, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 432, Loss: 0.009173043072223663, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 433, Loss: 0.009201506152749062, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 434, Loss: 0.008835367858409882, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 435, Loss: 0.008959904313087463, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 436, Loss: 0.009099123999476433, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 437, Loss: 0.009003404527902603, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 438, Loss: 0.0088726207613945, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 439, Loss: 0.008805682882666588, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 440, Loss: 0.008745488710701466, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 441, Loss: 0.008399601094424725, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 442, Loss: 0.008509796112775803, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 443, Loss: 0.008364764973521233, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 444, Loss: 0.00826648622751236, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 445, Loss: 0.008301744237542152, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 446, Loss: 0.008316436782479286, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 447, Loss: 0.008186906576156616, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 448, Loss: 0.007978403940796852, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 449, Loss: 0.007904685102403164, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 450, Loss: 0.008098572492599487, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 451, Loss: 0.00797964259982109, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 452, Loss: 0.007853472605347633, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 453, Loss: 0.0077092647552490234, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 454, Loss: 0.007732043042778969, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 455, Loss: 0.007670395076274872, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 456, Loss: 0.007888834923505783, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 457, Loss: 0.007463149260729551, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 458, Loss: 0.007378946524113417, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 459, Loss: 0.007627266459167004, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 460, Loss: 0.007234553806483746, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 461, Loss: 0.007269156165421009, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 462, Loss: 0.007106585893779993, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 463, Loss: 0.007325782440602779, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 464, Loss: 0.007211219519376755, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 465, Loss: 0.007208648137748241, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 466, Loss: 0.007206432521343231, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 467, Loss: 0.007018176838755608, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 468, Loss: 0.007035163696855307, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 469, Loss: 0.006961351726204157, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 470, Loss: 0.006766816135495901, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 471, Loss: 0.00692431814968586, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 472, Loss: 0.006981096230447292, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 473, Loss: 0.006844109855592251, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 474, Loss: 0.0067781866528093815, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 475, Loss: 0.006604350171983242, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 476, Loss: 0.006675665732473135, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 477, Loss: 0.006696880329400301, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 478, Loss: 0.006605394184589386, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 479, Loss: 0.00637988094240427, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 480, Loss: 0.0065617989748716354, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 481, Loss: 0.006438151933252811, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 482, Loss: 0.006422366946935654, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 483, Loss: 0.00628735451027751, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 484, Loss: 0.006487444043159485, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 485, Loss: 0.0061974856071174145, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 486, Loss: 0.006026264280080795, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 487, Loss: 0.00625417847186327, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 488, Loss: 0.006104862783104181, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 489, Loss: 0.006163203157484531, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 490, Loss: 0.006026844028383493, Train Accuracy: 1.0, Test Accuracy: 0.325
# Epoch 491, Loss: 0.005995390936732292, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 492, Loss: 0.006120777688920498, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 493, Loss: 0.005859230645000935, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 494, Loss: 0.005950354039669037, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 495, Loss: 0.005940649192780256, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 496, Loss: 0.005975556559860706, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 497, Loss: 0.00564291188493371, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 498, Loss: 0.005923653021454811, Train Accuracy: 1.0, Test Accuracy: 0.32
# Epoch 499, Loss: 0.005861142184585333, Train Accuracy: 1.0, Test Accuracy: 0.315
# Epoch 500, Loss: 0.005731014534831047, Train Accuracy: 1.0, Test Accuracy: 0.315
# {'learning_rate': 0.7, 'batch_size': 512}
# Epoch 1, Loss: 1.9351756572723389, Train Accuracy: 0.2125, Test Accuracy: 0.175
# Epoch 2, Loss: 1.905037522315979, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 3, Loss: 1.8883519172668457, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 4, Loss: 1.8763002157211304, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 5, Loss: 1.8668625354766846, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 6, Loss: 1.8706791400909424, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 7, Loss: 1.8593993186950684, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 8, Loss: 1.8650645017623901, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 9, Loss: 1.8576215505599976, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 10, Loss: 1.8588008880615234, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 11, Loss: 1.8558549880981445, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 12, Loss: 1.8523460626602173, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 13, Loss: 1.8447343111038208, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 14, Loss: 1.8517236709594727, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 15, Loss: 1.8592244386672974, Train Accuracy: 0.2525, Test Accuracy: 0.26
# Epoch 16, Loss: 1.8449947834014893, Train Accuracy: 0.25, Test Accuracy: 0.265
# Epoch 17, Loss: 1.85414457321167, Train Accuracy: 0.25125, Test Accuracy: 0.26
# Epoch 18, Loss: 1.8438081741333008, Train Accuracy: 0.25, Test Accuracy: 0.26
# Epoch 19, Loss: 1.8414655923843384, Train Accuracy: 0.255, Test Accuracy: 0.255
# Epoch 20, Loss: 1.8373241424560547, Train Accuracy: 0.2525, Test Accuracy: 0.26
# Epoch 21, Loss: 1.8344080448150635, Train Accuracy: 0.255, Test Accuracy: 0.255
# Epoch 22, Loss: 1.8334543704986572, Train Accuracy: 0.29, Test Accuracy: 0.265
# Epoch 23, Loss: 1.8429608345031738, Train Accuracy: 0.26, Test Accuracy: 0.255
# Epoch 24, Loss: 1.8300254344940186, Train Accuracy: 0.25625, Test Accuracy: 0.255
# Epoch 25, Loss: 1.8175113201141357, Train Accuracy: 0.2575, Test Accuracy: 0.255
# Epoch 26, Loss: 1.8186118602752686, Train Accuracy: 0.29125, Test Accuracy: 0.27
# Epoch 27, Loss: 1.8112930059432983, Train Accuracy: 0.2725, Test Accuracy: 0.26
# Epoch 28, Loss: 1.8141969442367554, Train Accuracy: 0.31125, Test Accuracy: 0.235
# Epoch 29, Loss: 1.8074650764465332, Train Accuracy: 0.2975, Test Accuracy: 0.27
# Epoch 30, Loss: 1.7868781089782715, Train Accuracy: 0.2825, Test Accuracy: 0.27
# Epoch 31, Loss: 1.783583402633667, Train Accuracy: 0.3075, Test Accuracy: 0.24
# Epoch 32, Loss: 1.7753101587295532, Train Accuracy: 0.30625, Test Accuracy: 0.255
# Epoch 33, Loss: 1.7729346752166748, Train Accuracy: 0.32, Test Accuracy: 0.23
# Epoch 34, Loss: 1.7487609386444092, Train Accuracy: 0.31375, Test Accuracy: 0.245
# Epoch 35, Loss: 1.7602791786193848, Train Accuracy: 0.34125, Test Accuracy: 0.225
# Epoch 36, Loss: 1.7578527927398682, Train Accuracy: 0.36125, Test Accuracy: 0.225
# Epoch 37, Loss: 1.7146153450012207, Train Accuracy: 0.3675, Test Accuracy: 0.25
# Epoch 38, Loss: 1.7096717357635498, Train Accuracy: 0.2875, Test Accuracy: 0.2
# Epoch 39, Loss: 1.7279331684112549, Train Accuracy: 0.31125, Test Accuracy: 0.195
# Epoch 40, Loss: 1.7524526119232178, Train Accuracy: 0.2475, Test Accuracy: 0.18
# Epoch 41, Loss: 1.7662204504013062, Train Accuracy: 0.35875, Test Accuracy: 0.28
# Epoch 42, Loss: 1.6549608707427979, Train Accuracy: 0.415, Test Accuracy: 0.225
# Epoch 43, Loss: 1.625730276107788, Train Accuracy: 0.42125, Test Accuracy: 0.235
# Epoch 44, Loss: 1.6022319793701172, Train Accuracy: 0.355, Test Accuracy: 0.215
# Epoch 45, Loss: 1.7426438331604004, Train Accuracy: 0.275, Test Accuracy: 0.2
# Epoch 46, Loss: 1.8409777879714966, Train Accuracy: 0.45, Test Accuracy: 0.24
# Epoch 47, Loss: 1.61004638671875, Train Accuracy: 0.415, Test Accuracy: 0.265
# Epoch 48, Loss: 1.5640559196472168, Train Accuracy: 0.4, Test Accuracy: 0.295
# Epoch 49, Loss: 1.533603549003601, Train Accuracy: 0.37, Test Accuracy: 0.28
# Epoch 50, Loss: 1.6646479368209839, Train Accuracy: 0.365, Test Accuracy: 0.285
# Epoch 51, Loss: 1.5259582996368408, Train Accuracy: 0.4225, Test Accuracy: 0.28
# Epoch 52, Loss: 1.4737110137939453, Train Accuracy: 0.5125, Test Accuracy: 0.22
# Epoch 53, Loss: 1.526958703994751, Train Accuracy: 0.2775, Test Accuracy: 0.175
# Epoch 54, Loss: 1.668309211730957, Train Accuracy: 0.47625, Test Accuracy: 0.305
# Epoch 55, Loss: 1.4065887928009033, Train Accuracy: 0.3625, Test Accuracy: 0.29
# Epoch 56, Loss: 1.7878786325454712, Train Accuracy: 0.2925, Test Accuracy: 0.16
# Epoch 57, Loss: 1.5678904056549072, Train Accuracy: 0.505, Test Accuracy: 0.3
# Epoch 58, Loss: 1.328941822052002, Train Accuracy: 0.56, Test Accuracy: 0.285
# Epoch 59, Loss: 1.2872029542922974, Train Accuracy: 0.46625, Test Accuracy: 0.285
# Epoch 60, Loss: 1.547339677810669, Train Accuracy: 0.47, Test Accuracy: 0.315
# Epoch 61, Loss: 1.4212005138397217, Train Accuracy: 0.3975, Test Accuracy: 0.24
# Epoch 62, Loss: 1.6558371782302856, Train Accuracy: 0.4825, Test Accuracy: 0.225
# Epoch 63, Loss: 1.4293849468231201, Train Accuracy: 0.42625, Test Accuracy: 0.215
# Epoch 64, Loss: 1.3500034809112549, Train Accuracy: 0.65875, Test Accuracy: 0.285
# Epoch 65, Loss: 1.1323894262313843, Train Accuracy: 0.46125, Test Accuracy: 0.21
# Epoch 66, Loss: 1.4562413692474365, Train Accuracy: 0.55375, Test Accuracy: 0.225
# Epoch 67, Loss: 1.1695849895477295, Train Accuracy: 0.60875, Test Accuracy: 0.23
# Epoch 68, Loss: 1.302056074142456, Train Accuracy: 0.25625, Test Accuracy: 0.185
# Epoch 69, Loss: 1.8438104391098022, Train Accuracy: 0.56875, Test Accuracy: 0.295
# Epoch 70, Loss: 1.177947998046875, Train Accuracy: 0.69875, Test Accuracy: 0.28
# Epoch 71, Loss: 1.0688018798828125, Train Accuracy: 0.47125, Test Accuracy: 0.18
# Epoch 72, Loss: 1.609603762626648, Train Accuracy: 0.37, Test Accuracy: 0.195
# Epoch 73, Loss: 1.2559776306152344, Train Accuracy: 0.72375, Test Accuracy: 0.31
# Epoch 74, Loss: 0.9442425966262817, Train Accuracy: 0.61, Test Accuracy: 0.305
# Epoch 75, Loss: 1.6235768795013428, Train Accuracy: 0.3825, Test Accuracy: 0.19
# Epoch 76, Loss: 2.0621252059936523, Train Accuracy: 0.3575, Test Accuracy: 0.15
# Epoch 77, Loss: 1.5519400835037231, Train Accuracy: 0.6225, Test Accuracy: 0.3
# Epoch 78, Loss: 1.2411001920700073, Train Accuracy: 0.66625, Test Accuracy: 0.29
# Epoch 79, Loss: 1.1136348247528076, Train Accuracy: 0.6425, Test Accuracy: 0.275
# Epoch 80, Loss: 1.1348209381103516, Train Accuracy: 0.4275, Test Accuracy: 0.185
# Epoch 81, Loss: 1.30165696144104, Train Accuracy: 0.64375, Test Accuracy: 0.31
# Epoch 82, Loss: 1.035271406173706, Train Accuracy: 0.5175, Test Accuracy: 0.305
# Epoch 83, Loss: 1.3155936002731323, Train Accuracy: 0.705, Test Accuracy: 0.28
# Epoch 84, Loss: 1.0186938047409058, Train Accuracy: 0.42375, Test Accuracy: 0.205
# Epoch 85, Loss: 1.322471022605896, Train Accuracy: 0.63875, Test Accuracy: 0.245
# Epoch 86, Loss: 0.9616281986236572, Train Accuracy: 0.79125, Test Accuracy: 0.325
# Epoch 87, Loss: 0.7327977418899536, Train Accuracy: 0.79125, Test Accuracy: 0.32
# Epoch 88, Loss: 0.8835490942001343, Train Accuracy: 0.59875, Test Accuracy: 0.255
# Epoch 89, Loss: 1.6006217002868652, Train Accuracy: 0.6125, Test Accuracy: 0.265
# Epoch 90, Loss: 1.0591801404953003, Train Accuracy: 0.7575, Test Accuracy: 0.34
# Epoch 91, Loss: 0.8842841386795044, Train Accuracy: 0.56375, Test Accuracy: 0.32
# Epoch 92, Loss: 1.480809211730957, Train Accuracy: 0.48, Test Accuracy: 0.21
# Epoch 93, Loss: 1.1427949666976929, Train Accuracy: 0.8375, Test Accuracy: 0.315
# Epoch 94, Loss: 0.6392627954483032, Train Accuracy: 0.86, Test Accuracy: 0.325
# Epoch 95, Loss: 0.5293543338775635, Train Accuracy: 0.79125, Test Accuracy: 0.295
# ...
# Epoch 302, Loss: 0.0003432735975366086, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 303, Loss: 0.00038015033351257443, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 304, Loss: 0.00035980003303848207, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 305, Loss: 0.0003842838923446834, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 306, Loss: 0.00035676165134646, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 307, Loss: 0.00038914577453397214, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 308, Loss: 0.0003675588814076036, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 309, Loss: 0.00035948376171290874, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 310, Loss: 0.0003420971625018865, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 311, Loss: 0.0003714041959028691, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 312, Loss: 0.0003488800139166415, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 313, Loss: 0.00034185784170404077, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 314, Loss: 0.00034848536597564816, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 315, Loss: 0.0003872872912324965, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 316, Loss: 0.0003274465852882713, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 317, Loss: 0.0003501364844851196, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 318, Loss: 0.00035263903555460274, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 319, Loss: 0.00033126521157100797, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 320, Loss: 0.00032338459277525544, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 321, Loss: 0.00034055084688588977, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 322, Loss: 0.00034252021578140557, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 323, Loss: 0.0003184220986440778, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 324, Loss: 0.0003136099549010396, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 325, Loss: 0.00031546689569950104, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 326, Loss: 0.00030508573399856687, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 327, Loss: 0.0003437389386817813, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 328, Loss: 0.0003072632534895092, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 329, Loss: 0.000310946605168283, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 330, Loss: 0.00030421739211305976, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 331, Loss: 0.00029068480944260955, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 332, Loss: 0.00031172684975899756, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 333, Loss: 0.0003318180388305336, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 334, Loss: 0.0003588374238461256, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 335, Loss: 0.00031815620604902506, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 336, Loss: 0.0003475213597994298, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 337, Loss: 0.0003155195736326277, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 338, Loss: 0.00030061486177146435, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 339, Loss: 0.0002972673100885004, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 340, Loss: 0.0002837303327396512, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 341, Loss: 0.0002877246879506856, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 342, Loss: 0.0003145537921227515, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 343, Loss: 0.00030117720598354936, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 344, Loss: 0.0003325568395666778, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 345, Loss: 0.0002962198341265321, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 346, Loss: 0.000305097084492445, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 347, Loss: 0.000309384980937466, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 348, Loss: 0.00029638494015671313, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 349, Loss: 0.0002940309641417116, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 350, Loss: 0.00029624972376041114, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 351, Loss: 0.0003439481370151043, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 352, Loss: 0.0002805714320857078, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 353, Loss: 0.0002633657131809741, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 354, Loss: 0.0002908409805968404, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 355, Loss: 0.00032056454801931977, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 356, Loss: 0.00025597563944756985, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 357, Loss: 0.000270178250502795, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 358, Loss: 0.00028398894937708974, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 359, Loss: 0.0002757187467068434, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 360, Loss: 0.00030605343636125326, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 361, Loss: 0.0002786539844237268, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 362, Loss: 0.00027623403002507985, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 363, Loss: 0.00026824980159290135, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 364, Loss: 0.0002896302321460098, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 365, Loss: 0.00026502570835873485, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 366, Loss: 0.0002808709687087685, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 367, Loss: 0.000287560629658401, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 368, Loss: 0.00025920988991856575, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 369, Loss: 0.0002667655353434384, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 370, Loss: 0.00027413759380578995, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 371, Loss: 0.0002517581160645932, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 372, Loss: 0.0002714851580094546, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 373, Loss: 0.0002667622466105968, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 374, Loss: 0.0002580553700681776, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 375, Loss: 0.0002639578888192773, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 376, Loss: 0.000296950398478657, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 377, Loss: 0.00025788828497752547, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 378, Loss: 0.00025093063595704734, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 379, Loss: 0.0002659107558429241, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 380, Loss: 0.0002657876757439226, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 381, Loss: 0.0002699487959034741, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 382, Loss: 0.0002406352577963844, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 383, Loss: 0.00025195645866915584, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 384, Loss: 0.0002476989757269621, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 385, Loss: 0.00025885304785333574, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 386, Loss: 0.0002504026051610708, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 387, Loss: 0.00026611643261276186, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 388, Loss: 0.0002426077553536743, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 389, Loss: 0.0002480114926584065, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 390, Loss: 0.00024574476992711425, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 391, Loss: 0.00024744050460867584, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 392, Loss: 0.0002708664978854358, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 393, Loss: 0.0002639019803609699, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 394, Loss: 0.00023874497856013477, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 395, Loss: 0.00024696337641216815, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 396, Loss: 0.00022504320077132434, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 397, Loss: 0.00023234561376739293, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 398, Loss: 0.0002443762496113777, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 399, Loss: 0.00023681443417444825, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 400, Loss: 0.0002366434782743454, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 401, Loss: 0.00023459692602045834, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 402, Loss: 0.00024251712602563202, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 403, Loss: 0.00024741044035181403, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 404, Loss: 0.00025874876882880926, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 405, Loss: 0.00022014317801222205, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 406, Loss: 0.0002349226560909301, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 407, Loss: 0.00021785779972560704, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 408, Loss: 0.0002563290181569755, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 409, Loss: 0.0002271458797622472, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 410, Loss: 0.00024207093520089984, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 411, Loss: 0.00022529982379637659, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 412, Loss: 0.00024592215777374804, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 413, Loss: 0.0002226943033747375, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 414, Loss: 0.0002590235380921513, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 415, Loss: 0.0002340189676033333, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 416, Loss: 0.00021769273735117167, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 417, Loss: 0.00021249261044431478, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 418, Loss: 0.0002279370673932135, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 419, Loss: 0.00022030918626114726, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 420, Loss: 0.00022427397198043764, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 421, Loss: 0.00023796223104000092, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 422, Loss: 0.00020403231610544026, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 423, Loss: 0.00021549194934777915, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 424, Loss: 0.00022607011487707496, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 425, Loss: 0.00020186914480291307, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 426, Loss: 0.00020665564807131886, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 427, Loss: 0.00021594390273094177, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 428, Loss: 0.00022197009820956737, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 429, Loss: 0.00020955601939931512, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 430, Loss: 0.0002276694285683334, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 431, Loss: 0.00024152774130925536, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 432, Loss: 0.00020620058057829738, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 433, Loss: 0.000207890581805259, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 434, Loss: 0.00022817662102170289, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 435, Loss: 0.00021560254390351474, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 436, Loss: 0.00022083037765696645, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 437, Loss: 0.00022017689479980618, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 438, Loss: 0.0002010909083765, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 439, Loss: 0.00021876579558011144, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 440, Loss: 0.00020214218238834292, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 441, Loss: 0.00022992391313891858, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 442, Loss: 0.00021634981385432184, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 443, Loss: 0.00020812629372812808, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 444, Loss: 0.00020596361719071865, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 445, Loss: 0.00020123027206864208, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 446, Loss: 0.00022108096163719893, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 447, Loss: 0.00020203297026455402, Train Accuracy: 1.0, Test Accuracy: 0.335
# Epoch 448, Loss: 0.00019940546189900488, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 449, Loss: 0.00020574437803588808, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 450, Loss: 0.00019182254618499428, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 451, Loss: 0.00019484784570522606, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 452, Loss: 0.00019005798094440252, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 453, Loss: 0.00018997576262336224, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 454, Loss: 0.00020472434698604047, Train Accuracy: 1.0, Test Accuracy: 0.345
# Epoch 455, Loss: 0.00020030660380143672, Train Accuracy: 1.0, Test Accuracy: 0.345
# Epoch 456, Loss: 0.00019977873307652771, Train Accuracy: 1.0, Test Accuracy: 0.345
# Epoch 457, Loss: 0.00018858766998164356, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 458, Loss: 0.00018907789490185678, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 459, Loss: 0.0002182665775762871, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 460, Loss: 0.0002027483278652653, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 461, Loss: 0.000196574634173885, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 462, Loss: 0.00019178020011167973, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 463, Loss: 0.00018052165978588164, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 464, Loss: 0.00020257123105693609, Train Accuracy: 1.0, Test Accuracy: 0.345
# Epoch 465, Loss: 0.0002032053453149274, Train Accuracy: 1.0, Test Accuracy: 0.345
# Epoch 466, Loss: 0.00018779387755785137, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 467, Loss: 0.00020174631208647043, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 468, Loss: 0.00018710337462835014, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 469, Loss: 0.0001765210326993838, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 470, Loss: 0.0001871487475000322, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 471, Loss: 0.00018362091213930398, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 472, Loss: 0.00018767541041597724, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 473, Loss: 0.0001932225131895393, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 474, Loss: 0.00018320002709515393, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 475, Loss: 0.00018776959041133523, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 476, Loss: 0.00018504368199501187, Train Accuracy: 1.0, Test Accuracy: 0.34
# Epoch 477, Loss: 0.000200246722670272, Train Accuracy: 1.0, Test Accuracy: 0.345
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-72dc7a5f635a> in <cell line: 4>()
#      36
#      37       optimizer.zero_grad()
# ---> 38       loss.backward()
#      39       optimizer.step()
#      40       losses_by_batch.append(loss.item())
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     579                 inputs=inputs,
#     580             )
# --> 581         torch.autograd.backward(
#     582             self, gradient, retain_graph, create_graph, inputs=inputs
#     583         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     823         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824     try:
# --> 825         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826             t_outputs, *args, **kwargs
#     827         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save our best model

# %%
# restore the best model we found in all that
model.load_state_dict(best_model)
print(f'test accuracy {compute_accuracy(model, test_loader)}')
print(f'train accuracy {compute_accuracy(model, train_loader)}')
torch.save(model.state_dict(), 'connect4_model_v3.pth')
# Out:
# test accuracy 0.345
# train accuracy 1.0

# %% [markdown]
# # Human vs model game

# %% [markdown]
# ## (OPTIONAL) Import existing model

# %%
# import preexisting model
model = Connect4MLP()
# model = torch.load('connect4_model_v1.pth')
model.load_state_dict(torch.load('connect4_model_v3.pth'))

print(f'test accuracy {compute_accuracy(model, test_loader)}')
print(f'train accuracy {compute_accuracy(model, train_loader)}')
# Out:
# <ipython-input-16-6d8d80be4faf>:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('connect4_model_v3.pth'))
# test accuracy 0.5749
# train accuracy 0.574275

# %%
# Function to play a game between human and model
def human_vs_model_game():
    board = initialize_board()
    game_over = False
    human_player = -1  # Let's assign Player O (-1) to human
    model_player = 1  # Player X will be the model
    current_turn = rand.choice([human_player, model_player])  # Randomly decide who starts

    buttons = []
    for i in range(7):
        button = widgets.Button(description=str(i+1), layout=widgets.Layout(width='30px'))
        button.on_click(lambda b, col=i: drop_piece_and_print(board, col, current_turn))
        buttons.append(button)



    def drop_piece_and_print(board, col, piece):
        nonlocal current_turn, game_over
        if game_over:
            return

        if is_valid_location(board, col):
            row = get_next_open_row(board, col)
            drop_piece(board, row, col, piece)

            won, winning_coords = winning_move(board, current_turn)
            if won:
                clear_output()
                print_board(board, winning_coords)
                print(f"Player {current_turn} wins!")
                return current_turn  # Return the winning player

            valid_columns = [col for col in range(7) if is_valid_location(board, col)]

            # Switch players
            current_turn *= -1

            # model plays its move
            with torch.inference_mode():
              valid_columns = [col for col in range(7) if is_valid_location(board, col)]
              next_move = recommend_valid_move(board, valid_columns)

            row = get_next_open_row(board, next_move)
            drop_piece(board, row, next_move, model_player)

            won, winning_coords = winning_move(board, current_turn)
            if won:
                clear_output()
                print_board(board, winning_coords)
                print(f"Player {current_turn} wins!")
                return current_turn  # Return the winning player

            current_turn *= -1
            clear_output()
            print_board(board, [])
            display(widgets.HBox(buttons))

            print(f'model played {next_move + 1}')

    if current_turn == model_player:
        valid_columns = [col for col in range(7) if is_valid_location(board, col)]

        col = recommend_move(board)
        row = get_next_open_row(board, col)
        drop_piece(board, row, col, model_player)

        won, winning_coords = winning_move(board, model_player)
        if won:
            clear_output()
            print_board(board, winning_coords)
            print(f"Player O wins!")
            game_over = True

        # Switch turns
        current_turn *= -1

        # Check for draw
        if np.all(board != 0) and not game_over:
            print_board(board, [])
            print("The game ended in a draw.")
            game_over = True


    print_board(board, [])
    display(widgets.HBox(buttons))

# Run the game function to play against the model
human_vs_model_game()
# Out:
# . . x o . . .
# . . x x . . .
# . . x x . . .
# . O O O O . .
# . o x o o . .
# x x x o x o .
#
# Player -1 wins!

# %% [markdown]
# # **Visualization**

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Define the layers
input_nodes = range(42)  # 42 input nodes (flattened board)
hidden1_nodes = range(42, 170)  # First hidden layer nodes
hidden2_nodes = range(170, 298)  # Second hidden layer nodes
output_nodes = range(298, 305)  # 7 output nodes (one for each column)

# Create a drastically simplified graph with only a subset of each layer's nodes
simplified_input_nodes = list(input_nodes)[:10]  # First 10 input nodes
simplified_hidden1_nodes = list(hidden1_nodes)[:10]  # First 10 hidden layer 1 nodes
simplified_hidden2_nodes = list(hidden2_nodes)[:5]  # First 5 hidden layer 2 nodes
simplified_output_nodes = list(output_nodes)[:5]  # All 5 output nodes

# Create a new graph for visualization
G_simplified = nx.DiGraph()

# Add nodes to the graph
G_simplified.add_nodes_from(simplified_input_nodes, layer="Input")
G_simplified.add_nodes_from(simplified_hidden1_nodes, layer="Hidden1")
G_simplified.add_nodes_from(simplified_hidden2_nodes, layer="Hidden2")
G_simplified.add_nodes_from(simplified_output_nodes, layer="Output")

# Add edges to simulate connections between layers
for i in simplified_input_nodes:
    for h1 in simplified_hidden1_nodes:
        G_simplified.add_edge(i, h1)
for h1 in simplified_hidden1_nodes:
    for h2 in simplified_hidden2_nodes:
        G_simplified.add_edge(h1, h2)
for h2 in simplified_hidden2_nodes:
    for o in simplified_output_nodes:
        G_simplified.add_edge(h2, o)

# Define positions for the simplified graph
pos_simplified = {}
layer_gap = 3

# Input Layer
for i, node in enumerate(simplified_input_nodes):
    pos_simplified[node] = (0, i - len(simplified_input_nodes) // 2)

# Hidden Layer 1
for i, node in enumerate(simplified_hidden1_nodes):
    pos_simplified[node] = (
        layer_gap,
        (i * len(simplified_input_nodes) / len(simplified_hidden1_nodes)) - len(simplified_input_nodes) // 2,
    )

# Hidden Layer 2
for i, node in enumerate(simplified_hidden2_nodes):
    pos_simplified[node] = (
        layer_gap * 2,
        (i * len(simplified_hidden1_nodes) / len(simplified_hidden2_nodes)) - len(simplified_input_nodes) // 2,
    )

# Output Layer
for i, node in enumerate(simplified_output_nodes):
    pos_simplified[node] = (
        layer_gap * 3,
        (i * len(simplified_hidden2_nodes) / len(simplified_output_nodes)) - len(simplified_input_nodes) // 2,
    )

# Draw the simplified graph
plt.figure(figsize=(10, 6))
nx.draw(
    G_simplified,
    pos_simplified,
    with_labels=False,
    node_size=50,  # Smaller nodes
    alpha=0.7,
    node_color="skyblue",
    edge_color="gray",
    width=0.2,  # Thinner edges
)
plt.title("Simplified Neural Network Architecture for Connect Four AI", fontsize=14)
plt.show()
